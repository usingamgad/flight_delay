# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path =r'C:\DRO\DCL_rawdata_files' # use your path
allFiles = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)

# %%
frame = pd.DataFrame()
frame = pd.concat(list_)

# %%
df_1 = pd.concat(pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_1/On_Time_On_Time_Performance_2016_1.csv')
df_2 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_2/On_Time_On_Time_Performance_2016_2.csv')
df_3 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_3/On_Time_On_Time_Performance_2016_3.csv')
df_4 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_4/On_Time_On_Time_Performance_2016_4.csv')
df_5 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_5/On_Time_On_Time_Performance_2016_5.csv')
df_6 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_6/On_Time_On_Time_Performance_2016_6.csv')
df_7 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_7/On_Time_On_Time_Performance_2016_7.csv')
df_8 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_8/On_Time_On_Time_Performance_2016_8.csv')
df_9 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_9/On_Time_On_Time_Performance_2016_9.csv')
df_10 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_10/On_Time_On_Time_Performance_2016_10.csv')
df_11 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_11/On_Time_On_Time_Performance_2016_11.csv')
df_12 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_12/On_Time_On_Time_Performance_2016_12.csv')
df_13 = pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2017_1/On_Time_On_Time_Performance_2017_1.csv')
# Out:
# /Users/mo186022/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (77) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mo186022/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mo186022/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mo186022/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (48,77,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
df = pd.concat([pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_1/On_Time_On_Time_Performance_2016_1.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_2/On_Time_On_Time_Performance_2016_2.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_3/On_Time_On_Time_Performance_2016_3.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_4/On_Time_On_Time_Performance_2016_4.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_5/On_Time_On_Time_Performance_2016_5.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_6/On_Time_On_Time_Performance_2016_6.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_7/On_Time_On_Time_Performance_2016_7.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_8/On_Time_On_Time_Performance_2016_8.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_9/On_Time_On_Time_Performance_2016_9.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_10/On_Time_On_Time_Performance_2016_10.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_11/On_Time_On_Time_Performance_2016_11.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2016_12/On_Time_On_Time_Performance_2016_12.csv')
,pd.read_csv('/Users/mo186022/Downloads/On_Time_On_Time_Performance_2017_1/On_Time_On_Time_Performance_2017_1.csv')])
# Out:
# /Users/mo186022/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (77) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mo186022/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mo186022/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mo186022/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (48,77,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %% [markdown]
# # Day of the week, Day of the month, month, UniqueCarrier, OriginAirportID, DestAirportID, CRSDepTime

# %%
float(df[df['DepDelay'] > 0].shape[0])/df.shape[0]
# Out:
# 0.3444744486149967

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2016        1      1           6          3  2016-01-06            AA
# 1  2016        1      1           7          4  2016-01-07            AA
# 2  2016        1      1           8          5  2016-01-08            AA
# 3  2016        1      1           9          6  2016-01-09            AA
# 4  2016        1      1          10          7  2016-01-10            AA
#
#    AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 0      19805      AA  N4YBAA      ...               NaN          NaN
# 1      19805      AA  N434AA      ...               NaN          NaN
# 2      19805      AA  N541AA      ...               NaN          NaN
# 3      19805      AA  N489AA      ...               NaN          NaN
# 4      19805      AA  N439AA      ...               NaN          NaN
#
#    Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# ...

# %%
df.shape
# Out:
# (6067675, 110)

# %%
df = df[df['Cancelled']<1] # The flight is cancelled

# %%
df.shape
# Out:
# (5992928, 110)

# %%
df = df[df['Diverted']<1] # The flight is diverted

# %%
df.shape
# Out:
# (5977790, 110)

# %%
###### Create a field for logistic regression

df['Class'] = 'No Delay'
df['Class'][(df['DepDelay'] >= 15) & (df['DepDelay'] < 30)] = 'Minor Delay'
df['Class'][(df['DepDelay'] >= 30) & (df['DepDelay'] < 60)] = 'Delay'
df['Class'][(df['DepDelay'] >= 60) & (df['DepDelay'] < 120)] = 'Significant Delay'
df['Class'][df['DepDelay'] > 120] = 'Severe Delay'
# Out:
# /Users/mo186022/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/mo186022/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/mo186022/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/mo186022/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# ...

# %%
df.groupby(['Class']).count()
# Out:
#                       Year  Quarter    Month  DayofMonth  DayOfWeek  \
# Class
# Delay               255070   255070   255070      255070     255070
# Minor Delay         309653   309653   309653      309653     309653
# No Delay           3988007  3988007  3988007     3988007    3988007
# Severe Delay       1251929  1251929  1251929     1251929    1251929
# Significant Delay   173131   173131   173131      173131     173131
#
#                    FlightDate  UniqueCarrier  AirlineID  Carrier  TailNum  \
# Class
# Delay                  255070         255070     255070   255070   255070
# Minor Delay            309653         309653     309653   309653   309653
# No Delay              3988007        3988007    3988007  3988007  3988007
# Severe Delay          1251929        1251929    1251929  1251929  1251929
# Significant Delay      173131         173131     173131   173131   173131
#
#                        ...       Div4TailNum  Div5Airport  Div5AirportID  \
# ...

# %%
std_pop = df['DepDelay'].mean() + 3*df['DepDelay'].std() # Need to normalize the flight delay time. removing outliers.

# %%
df.set_value(df[df['DepDelay'] < - std_pop].index.values,'DepDelay',- std_pop)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0       2016        1      1           6          3  2016-01-06            AA
# 1       2016        1      1           7          4  2016-01-07            AA
# 2       2016        1      1           8          5  2016-01-08            AA
# 3       2016        1      1           9          6  2016-01-09            AA
# 4       2016        1      1          10          7  2016-01-10            AA
# 5       2016        1      1          11          1  2016-01-11            AA
# 6       2016        1      1          12          2  2016-01-12            AA
# 7       2016        1      1          13          3  2016-01-13            AA
# 8       2016        1      1          14          4  2016-01-14            AA
# 9       2016        1      1          15          5  2016-01-15            AA
# 10      2016        1      1          16          6  2016-01-16            AA
# ...

# %%
df.set_value(df[df['DepDelay'] > std_pop].index.values,'DepDelay',std_pop)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0       2016        1      1           6          3  2016-01-06            AA
# 1       2016        1      1           7          4  2016-01-07            AA
# 2       2016        1      1           8          5  2016-01-08            AA
# 3       2016        1      1           9          6  2016-01-09            AA
# 4       2016        1      1          10          7  2016-01-10            AA
# 5       2016        1      1          11          1  2016-01-11            AA
# 6       2016        1      1          12          2  2016-01-12            AA
# 7       2016        1      1          13          3  2016-01-13            AA
# 8       2016        1      1          14          4  2016-01-14            AA
# 9       2016        1      1          15          5  2016-01-15            AA
# 10      2016        1      1          16          6  2016-01-16            AA
# ...

# %%
df['DepDelay'].max()
# Out:
# 129.6399294012854

# %%
df['DepDelay'].hist()

# %%
df.shape
# Out:
# (5977790, 111)

# %%
df_sub = df[['DayOfWeek', 'DayofMonth', 'Month', 'UniqueCarrier', 'OriginAirportID', 'DestAirportID', 'CRSDepTime','Distance', 'Class']]

# %%
df_sub = df_sub.dropna()

# %%
df_sub.dtypes
# Out:
# DayOfWeek            int64
# DayofMonth           int64
# Month                int64
# UniqueCarrier       object
# OriginAirportID      int64
# DestAirportID        int64
# CRSDepTime           int64
# Distance           float64
# Class               object
# dtype: object

# %%
df_sub.shape
# Out:
# (5977790, 9)

# %%
df_sub.DayOfWeek=df_sub.DayOfWeek.astype(str)

# %%
df_sub.DayofMonth=df_sub.DayofMonth.astype(str)

# %%
df_sub.Month=df_sub.Month.astype(str)

# %%
df_sub.OriginAirportID=df_sub.OriginAirportID.astype(str)

# %%
df_sub.DestAirportID=df_sub.DestAirportID.astype(str)

# %%
df_sub.dtypes
# Out:
# DayOfWeek           object
# DayofMonth          object
# Month               object
# UniqueCarrier       object
# OriginAirportID     object
# DestAirportID       object
# CRSDepTime           int64
# Distance           float64
# Class               object
# dtype: object

# %%
df_sub['DepDelay'].hist()

# %%
df_sub['DepDelay'].median()
# Out:
# 0.0

# %%
df_sub.set_value(df_sub[df_sub['DepDelay'] < 0].index.values,'DepDelay',0.001)
# Out:
#        DayOfWeek DayofMonth Month UniqueCarrier OriginAirportID DestAirportID  \
# 0              3          6     1            AA           11298         11433
# 1              4          7     1            AA           11298         11433
# 2              5          8     1            AA           11298         11433
# 3              6          9     1            AA           11298         11433
# 4              7         10     1            AA           11298         11433
# 5              1         11     1            AA           11298         11433
# 6              2         12     1            AA           11298         11433
# 7              3         13     1            AA           11298         11433
# 8              4         14     1            AA           11298         11433
# 9              5         15     1            AA           11298         11433
# 10             6         16     1            AA           11298         11433
# ...

# %%
df_sub.set_value(df_sub[df_sub['DepDelay'] == 0].index.values,'DepDelay',0.001)
# Out:
#        DayOfWeek DayofMonth Month UniqueCarrier OriginAirportID DestAirportID  \
# 0              3          6     1            AA           11298         11433
# 1              4          7     1            AA           11298         11433
# 2              5          8     1            AA           11298         11433
# 3              6          9     1            AA           11298         11433
# 4              7         10     1            AA           11298         11433
# 5              1         11     1            AA           11298         11433
# 6              2         12     1            AA           11298         11433
# 7              3         13     1            AA           11298         11433
# 8              4         14     1            AA           11298         11433
# 9              5         15     1            AA           11298         11433
# 10             6         16     1            AA           11298         11433
# ...

# %%
df_sub['DepDelay'].hist()

# %%
import math
import numpy as np

# %%
df_sub['DepDelayLog'] = df_sub['DepDelay'].apply(np.log)

# %%
df_sub['DepDelay'].hist()

# %%
from sklearn import preprocessing

# %%
ss = preprocessing.StandardScaler()

# %%
ss = ss.fit(df_sub['DepDelay'])
# Out:
# /Users/mo186022/anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
ss.transform(df_sub['DepDelay']).mean()
# Out:
# /Users/mo186022/anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# 3.3372909009587206e-16

# %%
df_sub['DepDelayNorm'] = ss.transform(df_sub['DepDelay'])
# Out:
# /Users/mo186022/anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
df_sub['DepDelayNorm'].hist()

# %%
df_sub['CRSDepHH'] = df_sub.CRSDepTime/100

# %%
df_sub['CRSDepHH'] = df_sub['CRSDepHH'].astype(int)

# %%
df_sub['CRSDepHH'].tail()
# Out:
# 450012     8
# 450013    14
# 450014    14
# 450015     7
# 450016    16
# Name: CRSDepHH, dtype: int64

# %%
df_sub.CRSDepTime.tail()
# Out:
# 450012     800
# 450013    1430
# 450014    1415
# 450015     755
# 450016    1620
# Name: CRSDepTime, dtype: int64

# %%
df_sub.sample(10)
# Out:
#        DayOfWeek DayofMonth Month UniqueCarrier OriginAirportID DestAirportID  \
# 210754         3         26    10            WN           10599         15304
# 370269         1         18     1            DL           11057         14869
# 94071          7         11     9            B6           12478         14747
# 324853         2         24     5            UA           14122         13930
# 421384         6          6     2            F9           11433         13204
# 180025         4         11     8            WN           13342         11278
# 59088          5         15     4            WN           12892         13796
# 354670         2          3     5            UA           13930         14771
# 173            3         23     3            AA           13851         11298
# 466410         1         20     6            EV           11481         12266
#
#         CRSDepTime  Distance    DepDelay  CRSDepHH
# 210754        1500     459.0   -3.000000        15
# ...

# %%
from sklearn import linear_model

# %%
reg = linear_model.Ridge (alpha = .5)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()

# %%
x, y = df_sub[['DayOfWeek', 
                'DayofMonth', 
               'Month', 
               #'UniqueCarrier', 
               'OriginAirportID', 
               'DestAirportID', 'Distance' ,
                'CRSDepHH']], df_sub['Class']

# %%
x.dtypes
# Out:
# DayOfWeek           object
# DayofMonth          object
# Month               object
# UniqueCarrier       object
# OriginAirportID     object
# DestAirportID       object
# Distance           float64
# CRSDepHH             int64
# dtype: object

# %%
x.sample()
# Out:
#        DayOfWeek DayofMonth Month UniqueCarrier OriginAirportID DestAirportID  \
# 428044         6         28     5            DL           13487         11433
#
#         Distance  CRSDepHH
# 428044     528.0        15

# %%
y.dtypes
# Out:
# dtype('O')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
#X_train = X_train.reshape(-1,1)

# %%
X_train.shape
# Out:
# (4184453, 8)

# %%
#y_train = y_train.reshape(-1,1)

# %%
y_train.shape
# Out:
# (4184453,)

# %%
reg = reg.fit(X_train,y_train)

# %%
# Decision Tree fitting a model
clf = clf.fit(X_train, y_train)

# %%
from sklearn.metrics import precision_recall_fscore_support

# %%
y_pred = clf.predict(X_train)

# %%
#Test
precision_recall_fscore_support(y_test, y_pred, average='macro')
# Out:
# (0.24941414180885363, 0.25465819431936582, 0.25153349882399256, None)

# %%
#Train
precision_recall_fscore_support(y_train, y_pred, average='macro')
# Out:
# (0.94989506027750159, 0.94091659959842089, 0.94315691258608358, None)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.70299614629040719

# %%
accuracy_score(y_train, y_pred)
# Out:
# 0.97916454074164527

# %%
reg.score(X_test,y_test)
# Out:
# 0.003890381560977096

# %%
reg.score(X_train,y_train)
# Out:
# 0.0037573519508004027

# %%
from sklearn.metrics import mean_absolute_error

# %%
y_pred = reg.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 45.163122235164323

# %%
y_train.mean()
# Out:
# 30.95114060748411

# %%
y_train.std()
# Out:
# 53.87006212809734

# %%
y_test.hist()

# %%
plt.scatter(y_test[:100],y_pred[:100])

# %%
import pickle
filename = 'final_model.sav'
pickle.dump(clf, open(filename, 'wb'))
